# %%
import sys

print(sys.executable)
# Out:
# /home/agus/projects/data-engineering-roadmap/.venv/bin/python

# %%
import pandas as pd

df = pd.DataFrame(
    {
        "country": ["Argentina", "Uruguay", "Brazil"],
        "transactions": [1500, 800, 2300],
    }
)

df
# Out:
#      country  transactions
# 0  Argentina          1500
# 1    Uruguay           800
# 2     Brazil          2300
